# %%
import pandas as pd
import xlsxwriter

# %%
df = pd.read_csv(r"D:\ME\Data Analytics Projects\Covid\CovidData.csv")
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 364163      ZWE    Africa     Zimbabwe  2023-12-10     265975.0        0.0
# 364164      ZWE    Africa     Zimbabwe  2023-12-11     265975.0        0.0
# 364165      ZWE    Africa     Zimbabwe  2023-12-12     265975.0        0.0
# 364166      ZWE    Africa     Zimbabwe  2023-12-13     265975.0        0.0
# 364167      ZWE    Africa     Zimbabwe  2023-12-14     265975.0        0.0
#
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 364163      ZWE    Africa     Zimbabwe  2023-12-10     265975.0        0.0
# 364164      ZWE    Africa     Zimbabwe  2023-12-11     265975.0        0.0
# 364165      ZWE    Africa     Zimbabwe  2023-12-12     265975.0        0.0
# 364166      ZWE    Africa     Zimbabwe  2023-12-13     265975.0        0.0
# 364167      ZWE    Africa     Zimbabwe  2023-12-14     265975.0        0.0
#
# ...

# %%
df.dropna(subset=["total_cases","total_deaths"], inplace=True)
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   16936
# location                                        0
# date                                            0
# total_cases                                     0
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       293046
# excess_mortality_cumulative                293046
# excess_mortality                           293046
# excess_mortality_cumulative_per_million    293046
# Length: 67, dtype: int64

# %%
df = df.reset_index(drop=True)
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-03-24         40.0       16.0
# 1           AFG      Asia  Afghanistan  2020-03-25         42.0        2.0
# 2           AFG      Asia  Afghanistan  2020-03-26         74.0       32.0
# 3           AFG      Asia  Afghanistan  2020-03-27         74.0        0.0
# 4           AFG      Asia  Afghanistan  2020-03-28         80.0        6.0
# ...         ...       ...          ...         ...          ...        ...
# 304295      ZWE    Africa     Zimbabwe  2023-12-10     265975.0        0.0
# 304296      ZWE    Africa     Zimbabwe  2023-12-11     265975.0        0.0
# 304297      ZWE    Africa     Zimbabwe  2023-12-12     265975.0        0.0
# 304298      ZWE    Africa     Zimbabwe  2023-12-13     265975.0        0.0
# 304299      ZWE    Africa     Zimbabwe  2023-12-14     265975.0        0.0
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16300\2457639793.py in <module>
# ----> 1 with pd.ExcelWriter(output_file, engine="xlsxwriter") as writer:
#       2     df.to_excel(writer, sheet_name="CovidData2023")
#
# NameError: name 'output_file' is not defined
